# %%
#importing needed libraries for analysis
import pandas as pd 
import os 
import matplotlib.pyplot as plt

#putting the csv file into a dataframe to be read by pandas
df = pd.read_csv('UT_Listings.csv')

#previewing first 5 lines of data. As you can see, the data needs to be cleaned up a bit before analysis.
df.head()
# Out:
#        Price                                Address  \
# 0  $150,000                                Plymouth
# 1  $150,000   CAMELOT MOBILE PARK | North Salt Lake
# 2  $150,000                            Taylorsville
# 3  $156,200                   WILKERSON | Roosevelt
# 4  $159,000                              Washington
#
#                              Details  \
# 0  \n3 BEDS  2 BATHS  \n1,866 SQFT\n
# 1  \n3 BEDS  2 BATHS  \n1,500 SQFT\n
# 2  \n4 BEDS  2 BATHS  \n1,344 SQFT\n
# 3  \n4 BEDS  2 BATHS  \n1,440 SQFT\n
# 4    \n1 BEDS  1 BATHS  \n432 SQFT\n
#
#                                                 Link
# 0  /property_listing/1801948/mlsname/WFRMLS/ltype...
# 1  /property_listing/1825267/mlsname/WFRMLS/ltype...
# 2  /property_listing/1822772/mlsname/WFRMLS/ltype...
# 3  /property_listing/1824246/mlsname/WFRMLS/ltype...
# 4  /property_listing/1818973/mlsname/WFRMLS/ltype...

# %%
#first, we are going to check for null values using the below code

nan_df = df[df.isna().any(axis=1)]
nan_df.head(50)

#as you can see, there is only 1 null value which was an advertising block from the site that we scraped.
# Out:
#       Price Address                  Details  \
# 5  $???,???     NaN  Thinking about selling?
#
#                                         Link
# 5  /fine/real/estate/marketeval/myid83735465

# %%
#because the only Nan value was in index 5, below we are dropping the 5th index. 
#You can see that it is no longer in our dataframe
df = df.drop(df.index[5], axis = 0)
df.head(10)
# Out:
#         Price                                Address  \
# 0   $150,000                                Plymouth
# 1   $150,000   CAMELOT MOBILE PARK | North Salt Lake
# 2   $150,000                            Taylorsville
# 3   $156,200                   WILKERSON | Roosevelt
# 4   $159,000                              Washington
# 6   $159,000                     ACORD LAKE | Salina
# 7   $159,900         MAJESTIC MEADOWS | Taylorsville
# 8   $159,900                  ASPEN HILLS | Fairview
# 9   $159,900                           MYTON | Myton
# 10  $159,900                              Malad City
#
#                               Details  \
# 0   \n3 BEDS  2 BATHS  \n1,866 SQFT\n
# 1   \n3 BEDS  2 BATHS  \n1,500 SQFT\n
# 2   \n4 BEDS  2 BATHS  \n1,344 SQFT\n
# 3   \n4 BEDS  2 BATHS  \n1,440 SQFT\n
# 4     \n1 BEDS  1 BATHS  \n432 SQFT\n
# 6     \n1 BEDS  1 BATHS  \n240 SQFT\n
# 7   \n3 BEDS  2 BATHS  \n1,386 SQFT\n
# 8     \n0 BEDS  1 BATHS  \n800 SQFT\n
# 9   \n2 BEDS  1 BATHS  \n1,050 SQFT\n
# 10    \n2 BEDS  1 BATHS  \n734 SQFT\n
#
#                                                  Link
# 0   /property_listing/1801948/mlsname/WFRMLS/ltype...
# 1   /property_listing/1825267/mlsname/WFRMLS/ltype...
# 2   /property_listing/1822772/mlsname/WFRMLS/ltype...
# 3   /property_listing/1824246/mlsname/WFRMLS/ltype...
# 4   /property_listing/1818973/mlsname/WFRMLS/ltype...
# 6   /property_listing/1811487/mlsname/WFRMLS/ltype...
# 7   /property_listing/1814321/mlsname/WFRMLS/ltype...
# 8   /property_listing/1814381/mlsname/WFRMLS/ltype...
# 9   /property_listing/1809578/mlsname/WFRMLS/ltype...
# 10  /property_listing/1811572/mlsname/WFRMLS/ltype...

# %%
#we previously had a $ in the Price column. This code removes the $ sign so that the column can be converted to an integer later on. 
df['Price'] = df['Price'].str.replace('$', '')
df['Price'] = df['Price'].str.replace(',', '')
df['Details'] = df['Details'].str.replace(',', '')
df.head()
# Out:
# C:\Users\trevp\AppData\Local\Temp\ipykernel_9184\912857771.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price'] = df['Price'].str.replace('$', '')
#      Price                                Address  \
# 0  150000                                Plymouth
# 1  150000   CAMELOT MOBILE PARK | North Salt Lake
# 2  150000                            Taylorsville
# 3  156200                   WILKERSON | Roosevelt
# 4  159000                              Washington
#
#                             Details  \
# 0  \n3 BEDS  2 BATHS  \n1866 SQFT\n
# 1  \n3 BEDS  2 BATHS  \n1500 SQFT\n
# 2  \n4 BEDS  2 BATHS  \n1344 SQFT\n
# 3  \n4 BEDS  2 BATHS  \n1440 SQFT\n
# 4   \n1 BEDS  1 BATHS  \n432 SQFT\n
#
#                                                 Link
# 0  /property_listing/1801948/mlsname/WFRMLS/ltype...
# 1  /property_listing/1825267/mlsname/WFRMLS/ltype...
# 2  /property_listing/1822772/mlsname/WFRMLS/ltype...
# 3  /property_listing/1824246/mlsname/WFRMLS/ltype...
# 4  /property_listing/1818973/mlsname/WFRMLS/ltype...

# %%
#Next - we need to create a new column representing just the city. As you can see from the data in the Address column, it
#also includes the neighborhood. This function below splits just the city and returns that to a new City column.
def get_city(address):
    return address.split('|')[-1]
    

df['City'] = df['Address'].apply(lambda x: f"{get_city(x)}")
df.head()
# Out:
#      Price                                Address  \
# 0  150000                                Plymouth
# 1  150000   CAMELOT MOBILE PARK | North Salt Lake
# 2  150000                            Taylorsville
# 3  156200                   WILKERSON | Roosevelt
# 4  159000                              Washington
#
#                             Details  \
# 0  \n3 BEDS  2 BATHS  \n1866 SQFT\n
# 1  \n3 BEDS  2 BATHS  \n1500 SQFT\n
# 2  \n4 BEDS  2 BATHS  \n1344 SQFT\n
# 3  \n4 BEDS  2 BATHS  \n1440 SQFT\n
# 4   \n1 BEDS  1 BATHS  \n432 SQFT\n
#
#                                                 Link              City
# 0  /property_listing/1801948/mlsname/WFRMLS/ltype...          Plymouth
# 1  /property_listing/1825267/mlsname/WFRMLS/ltype...   North Salt Lake
# 2  /property_listing/1822772/mlsname/WFRMLS/ltype...      Taylorsville
# 3  /property_listing/1824246/mlsname/WFRMLS/ltype...         Roosevelt
# 4  /property_listing/1818973/mlsname/WFRMLS/ltype...        Washington

# %%
#we are taking care of a lot in this block. 
#First - seperating all info from the details columns (bed, bath, sqft) into their own columns.
#Next - dropping the address and details columns altogether as we won't need them moving forward.

def get_beds(details):
    return details.split()[0]
def get_baths(details):
    return details.split()[2]
def get_sqft(details):
    return details.split()[-2]
    

df['Beds'] = df['Details'].apply(lambda x: f"{get_beds(x)}")
df['Baths'] = df['Details'].apply(lambda x: f"{get_baths(x)}")
df['Sqft'] = df['Details'].apply(lambda x: f"{get_sqft(x)}")

df.drop(df.columns[[1, 2]], axis=1, inplace=True)

df.head(10)
# Out:
#       Price                                               Link  \
# 0   150000   /property_listing/1801948/mlsname/WFRMLS/ltype...
# 1   150000   /property_listing/1825267/mlsname/WFRMLS/ltype...
# 2   150000   /property_listing/1822772/mlsname/WFRMLS/ltype...
# 3   156200   /property_listing/1824246/mlsname/WFRMLS/ltype...
# 4   159000   /property_listing/1818973/mlsname/WFRMLS/ltype...
# 6   159000   /property_listing/1811487/mlsname/WFRMLS/ltype...
# 7   159900   /property_listing/1814321/mlsname/WFRMLS/ltype...
# 8   159900   /property_listing/1814381/mlsname/WFRMLS/ltype...
# 9   159900   /property_listing/1809578/mlsname/WFRMLS/ltype...
# 10  159900   /property_listing/1811572/mlsname/WFRMLS/ltype...
#
#                 City Beds Baths  Sqft
# 0           Plymouth    3     2  1866
# 1    North Salt Lake    3     2  1500
# 2       Taylorsville    4     2  1344
# 3          Roosevelt    4     2  1440
# 4         Washington    1     1   432
# 6             Salina    1     1   240
# 7       Taylorsville    3     2  1386
# 8           Fairview    0     1   800
# 9              Myton    2     1  1050
# 10        Malad City    2     1   734

# %%
#here we are adding the https://www.dhomes4u.com to the link in order to complete it.
#Also - the initial Link column has been dropped.
df['Link2'] = "https://www.dhomes4u.com" + df['Link']
df.drop(df.columns[[1]],axis=1,inplace=True)
df.head()
# Out:
#      Price              City Beds Baths  Sqft  \
# 0  150000           Plymouth    3     2  1866
# 1  150000    North Salt Lake    3     2  1500
# 2  150000       Taylorsville    4     2  1344
# 3  156200          Roosevelt    4     2  1440
# 4  159000         Washington    1     1   432
#
#                                                Link2
# 0  https://www.dhomes4u.com/property_listing/1801...
# 1  https://www.dhomes4u.com/property_listing/1825...
# 2  https://www.dhomes4u.com/property_listing/1822...
# 3  https://www.dhomes4u.com/property_listing/1824...
# 4  https://www.dhomes4u.com/property_listing/1818...

# %%
#saving the clean file
df.to_csv('UT_Listings_Clean.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [370], in <cell line: 2>()
#       1 #saving the clean file
# ----> 2 df.to_csv('UT_Listings_Clean.csv', index=False)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
#    3557     compression=compression,
#    3558     quoting=quoting,
#    3559     columns=columns,
#    3560     index_label=index_label,
#    3561     mode=mode,
#    3562     chunksize=chunksize,
#    3563     quotechar=quotechar,
#    3564     date_format=date_format,
#    3565     doublequote=doublequote,
#    3566     escapechar=escapechar,
#    3567     storage_options=storage_options,
#    3568 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'UT_Listings_Clean.csv'

# %%
#making sure that we aren't missing any info
import numpy as np
for col in df.columns:
    pct_missing=np.mean(df[col].isnull())
    print('{}: {:.2f}%'.format(col, pct_missing))
# Out:
# Price: 0.00%
# City: 0.00%
# Beds: 0.00%
# Baths: 0.00%
# Sqft: 0.00%
# Link2: 0.00%

# %%
#needing to adjust the data types before analysis
print(df.dtypes)
# Out:
# Price    object
# City     object
# Beds     object
# Baths    object
# Sqft     object
# Link2    object
# dtype: object

# %%
#updating the value types here.
df = df.astype({'Price': 'int32', 'Beds': 'int32', 'Baths': 'int32', 'Sqft': 'int32', 'City': 'string'})

df.dtypes
# Out:
# Price     int32
# City     string
# Beds      int32
# Baths     int32
# Sqft      int32
# Link2    object
# dtype: object

# %%
#strong correlation between sqft and price. 
import seaborn as sns

sns.regplot(x = 'Sqft', y = 'Price', data = df)
# Out:
# <AxesSubplot:xlabel='Sqft', ylabel='Price'>

# %%
#showing numeric correlations only. Strongest correlation amongst numeric values is between sqft and price. Not surprising.
#It is interesting that there is a much stronger correlation between price - baths then price - beds. 
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot = True)
# Out:
# <AxesSubplot:>
